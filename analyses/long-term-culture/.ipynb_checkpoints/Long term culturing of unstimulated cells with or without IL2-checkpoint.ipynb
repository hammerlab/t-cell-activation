# %%
library('magrittr')
library('tibble')
library('dplyr')
library('tidyr')
library('ggplot2')
library('RColorBrewer')
library('readr')
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘tidyr’
#
# The following object is masked from ‘package:magrittr’:
#
#     extract

# %%
il2_data <- 
    read_tsv(
        "data.tsv",
        col_types=cols(
            `Sample:`=col_character(),
            `Week`=col_factor(levels=c('Week 1', 'Week 2', 'Week 3', 'Week 4')),
            `Donor`=col_factor(levels=c('Donor 42', 'Donor 43')),
            `Condition`=col_factor(levels=c('no IL2', '200 IU/mL IL2')),
            .default=col_double()
        )
    )

il2_data %>% head
# Out:
#   Sample: Week   Donor    Condition     Count   Live | Freq. of Parent
# 1 1.fcs   Week 4 Donor 42 no IL2        1150000 21.9
# 2 2.fcs   Week 4 Donor 42 no IL2        1090000 22.1
# 3 3.fcs   Week 4 Donor 42 no IL2         983000 20.8
# 4 4.fcs   Week 4 Donor 42 200 IU/mL IL2 1650000 75.2
# 5 5.fcs   Week 4 Donor 42 200 IU/mL IL2 1600000 76.1
# 6 6.fcs   Week 4 Donor 42 200 IU/mL IL2 1690000 75.8
#   Live/CCR7+ CD45RO+ | Freq. of Parent Live/CCR7+ CD45RO- | Freq. of Parent
# 1 36.5                                 17.7
# 2 39.7                                 16.3
# 3 38.5                                 13.6
# 4 20.3                                 18.2
# 5 19.3                                 18.5
# 6 19.2                                 18.3
#   Live/CCR7- CD45RO+ | Freq. of Parent Live/CCR7- CD45RO- | Freq. of Parent
# 1 42.5                                  3.31
# 2 40.2                                  3.83
# 3 44.0                                  3.89
# 4 44.2                                 17.30
# 5 44.6                                 17.60
# 6 44.3                                 18.20
#   Live/CD4+ CD8+ | Freq. of Parent Live/CD4+ CD8- | Freq. of Parent
# 1 1.95                             85.6
# 2 1.97                             85.6
# 3 1.82                             85.5
# 4 5.50                             49.7
# 5 4.83                             50.1
# 6 4.92                             50.0
#   Live/CD4- CD8+ | Freq. of Parent Live/CD4- CD8- | Freq. of Parent
# 1 10.8                             1.58
# 2 10.7                             1.75
# 3 11.0                             1.60
# 4 41.0                             3.79
# 5 41.3                             3.82
# 6 41.3                             3.83

# %%
il2_data %>%
    group_by(`Week`, `Donor`, `Condition`) %>%
    summarize(
        `Avg_count`=mean(`Count`),
        `Sd_count`=sd(`Count`)
    ) %>%
    ggplot(aes(x=`Week`, y=`Avg_count`, color=`Condition`)) +
    geom_line(aes(group=`Condition`), size=1.5) +
    geom_errorbar(
        aes(
            ymin=`Avg_count`-`Sd_count`,
            ymax=`Avg_count`+`Sd_count`
        ),
        width=.2,
        alpha=.5
    ) +
    facet_wrap(~`Donor`, nrow=2) +
    ylab('Cell count')
# Out:
# plot without title

# %%
il2_data %>%
    group_by(`Week`, `Donor`, `Condition`) %>%
    summarize(
        `Avg_flive`=mean(`Live | Freq. of Parent`),
        `Sd_flive`=sd(`Live | Freq. of Parent`)
    ) %>%
    ggplot(aes(x=`Week`, y=`Avg_flive`, color=`Condition`)) +
    geom_line(aes(group=`Condition`), size=1.5) +
    geom_errorbar(
        aes(
            ymin=`Avg_flive`-`Sd_flive`,
            ymax=`Avg_flive`+`Sd_flive`
        ),
        width=.2,
        alpha=.5
    ) +
    facet_wrap(~`Donor`, nrow=2) +
    ylab('Percent live (%)') +
    ylim(0, 100)
# Out:
# plot without title

# %%
il2_data %>%
    mutate(`Live count`=`Count` * (`Live | Freq. of Parent`/100)) %>%
    group_by(`Week`, `Donor`, `Condition`) %>%
    summarize(
        `Avg_lcount`=mean(`Live count`),
        `Sd_lcount`=sd(`Live count`)
    ) %>%
    ggplot(aes(x=`Week`, y=`Avg_lcount`, color=`Condition`)) +
    geom_line(aes(group=`Condition`), size=1.5) +
    geom_errorbar(
        aes(
            ymin=`Avg_lcount`-`Sd_lcount`,
            ymax=`Avg_lcount`+`Sd_lcount`
        ),
        width=.2,
        alpha=.5
    ) +
    facet_wrap(~`Donor`, nrow=2) +
    ylab('Live cell count') +
    ylim(0, NA) +
    xlab('')
# Out:
# plot without title

# %%
naive_data <-
    il2_data %>%
    select(
        `Week`:`Live | Freq. of Parent`,
        `Naive`=`Live/CCR7+ CD45RO- | Freq. of Parent`,
        `CM`=`Live/CCR7+ CD45RO+ | Freq. of Parent`,
        `EM`=`Live/CCR7- CD45RO+ | Freq. of Parent`,
        `EMRA`=`Live/CCR7- CD45RO- | Freq. of Parent`
    ) %>%
    gather(
        key='Population',
        value='Population Frequency',
        factor_key=TRUE,
        `Naive`:`EMRA`
    ) %>%
    mutate(
        `Population count`=`Count` * (`Population Frequency`/100) * (`Live | Freq. of Parent`/100)
    ) %>%
    group_by(`Week`, `Donor`, `Condition`, `Population`) %>%
    summarize(
        `Avg_freq`=mean(`Population Frequency`),
        `Sd_freq`=sd(`Population Frequency`),
        `Avg_pcount`=mean(`Population count`),
        `Sd_pcount`=sd(`Population count`)
    )

naive_data %>% head
# Out:
#   Week   Donor    Condition     Population Avg_freq Sd_freq   Avg_pcount
# 1 Week 1 Donor 42 no IL2        Naive      41.26667 0.3055050 373293.1
# 2 Week 1 Donor 42 no IL2        CM         31.96667 0.5033223 289004.1
# 3 Week 1 Donor 42 no IL2        EM         13.46667 0.3511885 121974.6
# 4 Week 1 Donor 42 no IL2        EMRA       13.26667 0.4041452 120135.4
# 5 Week 1 Donor 42 200 IU/mL IL2 Naive      34.90000 0.6082763 428098.2
# 6 Week 1 Donor 42 200 IU/mL IL2 CM         28.00000 0.3464102 343508.3
#   Sd_pcount
# 1 24054.33
# 2 14999.83
# 3 11351.07
# 4 11025.09
# 5 15756.78
# 6 13780.62

# %%
naive_data %>%
    ggplot(aes(x=`Week`, y=`Avg_freq`, color=`Condition`)) +
        geom_line(aes(group=`Condition`), size=1.5) +
        geom_errorbar(
            aes(
                ymin=`Avg_freq`-`Sd_freq`,
                ymax=`Avg_freq`+`Sd_freq`
            ),
            width=.2,
            alpha=.5
        ) +
        facet_grid(`Donor`~`Population`) +
        theme(axis.text.x=element_text(angle=75, hjust=1)) +
        xlab("") +
        ylab("Percent population (%)")
# Out:
# plot without title

# %%
naive_data %>%
    ggplot(aes(x=`Week`, y=`Avg_pcount`, color=`Condition`)) +
        geom_line(aes(group=`Condition`), size=1.5) +
        geom_errorbar(
            aes(
                ymin=`Avg_pcount`-`Sd_pcount`,
                ymax=`Avg_pcount`+`Sd_pcount`
            ),
            width=.2,
            alpha=.5
        ) +
        facet_grid(`Donor`~`Population`) +
        theme(axis.text.x=element_text(angle=75, hjust=1)) +
        xlab("") +
        ylab("Cell count")
# Out:
# plot without title

# %%
cd48_data <-
    il2_data %>%
    select(
        `Week`:`Live | Freq. of Parent`,
        `CD4+ CD8-`=`Live/CD4+ CD8- | Freq. of Parent`,
        `CD4+ CD8+`=`Live/CD4+ CD8+ | Freq. of Parent`,
        `CD4- CD8+`=`Live/CD4- CD8+ | Freq. of Parent`,
        `CD4- CD8-`=`Live/CD4- CD8- | Freq. of Parent`
    ) %>%
    gather(
        key='Population',
        value='Population Frequency',
        factor_key=TRUE,
        `CD4+ CD8-`:`CD4- CD8-`
    ) %>%
    mutate(
        `Population count`=`Count` * (`Population Frequency`/100) * (`Live | Freq. of Parent`/100)
    ) %>%
    group_by(`Week`, `Donor`, `Condition`, `Population`) %>%
    summarize(
        `Avg_freq`=mean(`Population Frequency`),
        `Sd_freq`=sd(`Population Frequency`),
        `Avg_pcount`=mean(`Population count`),
        `Sd_pcount`=sd(`Population count`)
    )

cd48_data %>% head
# Out:
#   Week   Donor    Condition     Population Avg_freq   Sd_freq    Avg_pcount
# 1 Week 1 Donor 42 no IL2        CD4+ CD8-  71.5666667 0.05773503 647470.416
# 2 Week 1 Donor 42 no IL2        CD4+ CD8+   3.0600000 0.07810250  27709.011
# 3 Week 1 Donor 42 no IL2        CD4- CD8+  24.5000000 0.00000000 221653.215
# 4 Week 1 Donor 42 no IL2        CD4- CD8-   0.8766667 0.04932883   7912.432
# 5 Week 1 Donor 42 200 IU/mL IL2 CD4+ CD8-  61.3000000 0.10000000 752363.258
# 6 Week 1 Donor 42 200 IU/mL IL2 CD4+ CD8+   4.5000000 0.23579652  55289.454
#   Sd_pcount
# 1 43633.167
# 2  2442.788
# 3 14915.849
# 4   196.216
# 5 39598.087
# 6  5076.931

# %%
cd48_data %>%
    ggplot(aes(x=`Week`, y=`Avg_freq`, color=`Condition`)) +
        geom_line(aes(group=`Condition`), size=1.5) +
        geom_errorbar(
            aes(
                ymin=`Avg_freq`-`Sd_freq`,
                ymax=`Avg_freq`+`Sd_freq`
            ),
            width=.2,
            alpha=.5
        ) +
        facet_grid(`Donor`~`Population`) +
        theme(axis.text.x=element_text(angle=75, hjust=1)) +
        xlab("") +
        ylab("Percent population (%)")
# Out:
# plot without title

# %%
cd48_data %>%
    ggplot(aes(x=`Week`, y=`Avg_pcount`, color=`Condition`)) +
        geom_line(aes(group=`Condition`), size=1.5) +
        geom_errorbar(
            aes(
                ymin=`Avg_pcount`-`Sd_pcount`,
                ymax=`Avg_pcount`+`Sd_pcount`
            ),
            width=.2,
            alpha=.5
        ) +
        facet_grid(`Donor`~`Population`) +
        theme(axis.text.x=element_text(angle=75, hjust=1)) +
        xlab("") +
        ylab("Cell count")
# Out:
# plot without title
